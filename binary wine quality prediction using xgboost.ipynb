# %% [raw]
# feature selection or pca , ruc-auc curve and web app ,deployment

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('D:\MLProjects\Red wine\wine_data.csv')

# %%
df.head().style.background_gradient()
# Out:
# <style type="text/css">
# #T_e308a_row0_col0, #T_e308a_row0_col2, #T_e308a_row0_col3, #T_e308a_row0_col5, #T_e308a_row0_col6, #T_e308a_row0_col9, #T_e308a_row0_col10, #T_e308a_row0_col11, #T_e308a_row1_col2, #T_e308a_row1_col7, #T_e308a_row1_col11, #T_e308a_row2_col11, #T_e308a_row3_col1, #T_e308a_row3_col3, #T_e308a_row3_col4, #T_e308a_row3_col8, #T_e308a_row4_col0, #T_e308a_row4_col2, #T_e308a_row4_col3, #T_e308a_row4_col5, #T_e308a_row4_col6, #T_e308a_row4_col9, #T_e308a_row4_col10, #T_e308a_row4_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e308a_row0_col1, #T_e308a_row4_col1 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_e308a_row0_col4, #T_e308a_row4_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e308a_row0_col7, #T_e308a_row4_col7 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_e308a_row0_col8, #T_e308a_row1_col1, #T_e308a_row1_col3, #T_e308a_row1_col4, #T_e308a_row1_col5, #T_e308a_row1_col6, #T_e308a_row1_col9, #T_e308a_row1_col10, #T_e308a_row2_col10, #T_e308a_row3_col0, #T_e308a_row3_col2, #T_e308a_row3_col7, #T_e308a_row3_col10, #T_e308a_row3_col11, #T_e308a_row4_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e308a_row1_col0, #T_e308a_row2_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e308a_row1_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_e308a_row2_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_e308a_row2_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e308a_row2_col3 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_e308a_row2_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_e308a_row2_col5, #T_e308a_row2_col8 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_e308a_row2_col6 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_e308a_row2_col7, #T_e308a_row3_col9 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_e308a_row2_col9 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_e308a_row3_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_e308a_row3_col6 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e308a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fixed acidity</th>
#       <th class="col_heading level0 col1" >volatile acidity</th>
#       <th class="col_heading level0 col2" >citric acid</th>
#       <th class="col_heading level0 col3" >residual sugar</th>
#       <th class="col_heading level0 col4" >chlorides</th>
#       <th class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th class="col_heading level0 col7" >density</th>
#       <th class="col_heading level0 col8" >pH</th>
#       <th class="col_heading level0 col9" >sulphates</th>
#       <th class="col_heading level0 col10" >alcohol</th>
#       <th class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e308a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e308a_row0_col0" class="data row0 col0" >7.400000</td>
#       <td id="T_e308a_row0_col1" class="data row0 col1" >0.700000</td>
#       <td id="T_e308a_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e308a_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_e308a_row0_col4" class="data row0 col4" >0.076000</td>
#       <td id="T_e308a_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_e308a_row0_col6" class="data row0 col6" >34.000000</td>
#       <td id="T_e308a_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_e308a_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_e308a_row0_col9" class="data row0 col9" >0.560000</td>
#       <td id="T_e308a_row0_col10" class="data row0 col10" >9.400000</td>
#       <td id="T_e308a_row0_col11" class="data row0 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e308a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e308a_row1_col0" class="data row1 col0" >7.800000</td>
#       <td id="T_e308a_row1_col1" class="data row1 col1" >0.880000</td>
#       <td id="T_e308a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e308a_row1_col3" class="data row1 col3" >2.600000</td>
#       <td id="T_e308a_row1_col4" class="data row1 col4" >0.098000</td>
#       <td id="T_e308a_row1_col5" class="data row1 col5" >25.000000</td>
#       <td id="T_e308a_row1_col6" class="data row1 col6" >67.000000</td>
#       <td id="T_e308a_row1_col7" class="data row1 col7" >0.996800</td>
#       <td id="T_e308a_row1_col8" class="data row1 col8" >3.200000</td>
#       <td id="T_e308a_row1_col9" class="data row1 col9" >0.680000</td>
#       <td id="T_e308a_row1_col10" class="data row1 col10" >9.800000</td>
#       <td id="T_e308a_row1_col11" class="data row1 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e308a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e308a_row2_col0" class="data row2 col0" >7.800000</td>
#       <td id="T_e308a_row2_col1" class="data row2 col1" >0.760000</td>
#       <td id="T_e308a_row2_col2" class="data row2 col2" >0.040000</td>
#       <td id="T_e308a_row2_col3" class="data row2 col3" >2.300000</td>
#       <td id="T_e308a_row2_col4" class="data row2 col4" >0.092000</td>
#       <td id="T_e308a_row2_col5" class="data row2 col5" >15.000000</td>
#       <td id="T_e308a_row2_col6" class="data row2 col6" >54.000000</td>
#       <td id="T_e308a_row2_col7" class="data row2 col7" >0.997000</td>
#       <td id="T_e308a_row2_col8" class="data row2 col8" >3.260000</td>
#       <td id="T_e308a_row2_col9" class="data row2 col9" >0.650000</td>
#       <td id="T_e308a_row2_col10" class="data row2 col10" >9.800000</td>
#       <td id="T_e308a_row2_col11" class="data row2 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e308a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e308a_row3_col0" class="data row3 col0" >11.200000</td>
#       <td id="T_e308a_row3_col1" class="data row3 col1" >0.280000</td>
#       <td id="T_e308a_row3_col2" class="data row3 col2" >0.560000</td>
#       <td id="T_e308a_row3_col3" class="data row3 col3" >1.900000</td>
#       <td id="T_e308a_row3_col4" class="data row3 col4" >0.075000</td>
#       <td id="T_e308a_row3_col5" class="data row3 col5" >17.000000</td>
#       <td id="T_e308a_row3_col6" class="data row3 col6" >60.000000</td>
#       <td id="T_e308a_row3_col7" class="data row3 col7" >0.998000</td>
#       <td id="T_e308a_row3_col8" class="data row3 col8" >3.160000</td>
#       <td id="T_e308a_row3_col9" class="data row3 col9" >0.580000</td>
#       <td id="T_e308a_row3_col10" class="data row3 col10" >9.800000</td>
#       <td id="T_e308a_row3_col11" class="data row3 col11" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e308a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e308a_row4_col0" class="data row4 col0" >7.400000</td>
#       <td id="T_e308a_row4_col1" class="data row4 col1" >0.700000</td>
#       <td id="T_e308a_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_e308a_row4_col3" class="data row4 col3" >1.900000</td>
#       <td id="T_e308a_row4_col4" class="data row4 col4" >0.076000</td>
#       <td id="T_e308a_row4_col5" class="data row4 col5" >11.000000</td>
#       <td id="T_e308a_row4_col6" class="data row4 col6" >34.000000</td>
#       <td id="T_e308a_row4_col7" class="data row4 col7" >0.997800</td>
#       <td id="T_e308a_row4_col8" class="data row4 col8" >3.510000</td>
#       <td id="T_e308a_row4_col9" class="data row4 col9" >0.560000</td>
#       <td id="T_e308a_row4_col10" class="data row4 col10" >9.400000</td>
#       <td id="T_e308a_row4_col11" class="data row4 col11" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info(memory_usage=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)

# %% [raw]
# No null values here. Data has 12 columns, all the Independent columns are float type means all the vALUES are continuous. so, yes we can use gaussianNaivebayes

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_4de47_row0_col0, #T_4de47_row0_col1, #T_4de47_row0_col2, #T_4de47_row0_col3, #T_4de47_row0_col4, #T_4de47_row0_col5, #T_4de47_row0_col6, #T_4de47_row0_col7, #T_4de47_row0_col8, #T_4de47_row0_col9, #T_4de47_row0_col10, #T_4de47_row0_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4de47_row1_col0, #T_4de47_row1_col10, #T_4de47_row2_col5, #T_4de47_row3_col10, #T_4de47_row4_col10, #T_4de47_row5_col10, #T_4de47_row6_col0, #T_4de47_row6_col10, #T_4de47_row7_col11 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_4de47_row1_col1, #T_4de47_row1_col2, #T_4de47_row1_col3, #T_4de47_row1_col4, #T_4de47_row1_col7, #T_4de47_row1_col8, #T_4de47_row1_col9, #T_4de47_row1_col11, #T_4de47_row2_col0, #T_4de47_row2_col1, #T_4de47_row2_col2, #T_4de47_row2_col3, #T_4de47_row2_col4, #T_4de47_row2_col7, #T_4de47_row2_col8, #T_4de47_row2_col9, #T_4de47_row2_col10, #T_4de47_row2_col11, #T_4de47_row3_col0, #T_4de47_row3_col1, #T_4de47_row3_col2, #T_4de47_row3_col3, #T_4de47_row3_col4, #T_4de47_row3_col5, #T_4de47_row3_col6, #T_4de47_row3_col7, #T_4de47_row3_col8, #T_4de47_row3_col9, #T_4de47_row3_col11, #T_4de47_row4_col0, #T_4de47_row4_col1, #T_4de47_row4_col2, #T_4de47_row4_col3, #T_4de47_row4_col4, #T_4de47_row4_col5, #T_4de47_row4_col7, #T_4de47_row4_col8, #T_4de47_row4_col9, #T_4de47_row4_col11, #T_4de47_row5_col0, #T_4de47_row5_col1, #T_4de47_row5_col2, #T_4de47_row5_col3, #T_4de47_row5_col4, #T_4de47_row5_col7, #T_4de47_row5_col8, #T_4de47_row5_col9, #T_4de47_row5_col11, #T_4de47_row6_col1, #T_4de47_row6_col2, #T_4de47_row6_col3, #T_4de47_row6_col4, #T_4de47_row6_col7, #T_4de47_row6_col8, #T_4de47_row6_col9, #T_4de47_row6_col11, #T_4de47_row7_col1, #T_4de47_row7_col2, #T_4de47_row7_col4, #T_4de47_row7_col7, #T_4de47_row7_col8, #T_4de47_row7_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4de47_row1_col5, #T_4de47_row4_col6, #T_4de47_row5_col5, #T_4de47_row7_col0, #T_4de47_row7_col3, #T_4de47_row7_col10 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_4de47_row1_col6 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_4de47_row2_col6, #T_4de47_row6_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_4de47_row5_col6 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_4de47_row6_col6 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_4de47_row7_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_4de47_row7_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# </style>
# <table id="T_4de47_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fixed acidity</th>
#       <th class="col_heading level0 col1" >volatile acidity</th>
#       <th class="col_heading level0 col2" >citric acid</th>
#       <th class="col_heading level0 col3" >residual sugar</th>
#       <th class="col_heading level0 col4" >chlorides</th>
#       <th class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th class="col_heading level0 col7" >density</th>
#       <th class="col_heading level0 col8" >pH</th>
#       <th class="col_heading level0 col9" >sulphates</th>
#       <th class="col_heading level0 col10" >alcohol</th>
#       <th class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4de47_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_4de47_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_4de47_row0_col1" class="data row0 col1" >1599.000000</td>
#       <td id="T_4de47_row0_col2" class="data row0 col2" >1599.000000</td>
#       <td id="T_4de47_row0_col3" class="data row0 col3" >1599.000000</td>
#       <td id="T_4de47_row0_col4" class="data row0 col4" >1599.000000</td>
#       <td id="T_4de47_row0_col5" class="data row0 col5" >1599.000000</td>
#       <td id="T_4de47_row0_col6" class="data row0 col6" >1599.000000</td>
#       <td id="T_4de47_row0_col7" class="data row0 col7" >1599.000000</td>
#       <td id="T_4de47_row0_col8" class="data row0 col8" >1599.000000</td>
#       <td id="T_4de47_row0_col9" class="data row0 col9" >1599.000000</td>
#       <td id="T_4de47_row0_col10" class="data row0 col10" >1599.000000</td>
#       <td id="T_4de47_row0_col11" class="data row0 col11" >1599.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4de47_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_4de47_row1_col0" class="data row1 col0" >8.319637</td>
#       <td id="T_4de47_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_4de47_row1_col2" class="data row1 col2" >0.270976</td>
#       <td id="T_4de47_row1_col3" class="data row1 col3" >2.538806</td>
#       <td id="T_4de47_row1_col4" class="data row1 col4" >0.087467</td>
#       <td id="T_4de47_row1_col5" class="data row1 col5" >15.874922</td>
#       <td id="T_4de47_row1_col6" class="data row1 col6" >46.467792</td>
#       <td id="T_4de47_row1_col7" class="data row1 col7" >0.996747</td>
#       <td id="T_4de47_row1_col8" class="data row1 col8" >3.311113</td>
#       <td id="T_4de47_row1_col9" class="data row1 col9" >0.658149</td>
#       <td id="T_4de47_row1_col10" class="data row1 col10" >10.422983</td>
#       <td id="T_4de47_row1_col11" class="data row1 col11" >5.636023</td>
#     </tr>
#     <tr>
#       <th id="T_4de47_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_4de47_row2_col0" class="data row2 col0" >1.741096</td>
#       <td id="T_4de47_row2_col1" class="data row2 col1" >0.179060</td>
#       <td id="T_4de47_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_4de47_row2_col3" class="data row2 col3" >1.409928</td>
#       <td id="T_4de47_row2_col4" class="data row2 col4" >0.047065</td>
#       <td id="T_4de47_row2_col5" class="data row2 col5" >10.460157</td>
#       <td id="T_4de47_row2_col6" class="data row2 col6" >32.895324</td>
#       <td id="T_4de47_row2_col7" class="data row2 col7" >0.001887</td>
#       <td id="T_4de47_row2_col8" class="data row2 col8" >0.154386</td>
#       <td id="T_4de47_row2_col9" class="data row2 col9" >0.169507</td>
#       <td id="T_4de47_row2_col10" class="data row2 col10" >1.065668</td>
#       <td id="T_4de47_row2_col11" class="data row2 col11" >0.807569</td>
#     </tr>
#     <tr>
#       <th id="T_4de47_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_4de47_row3_col0" class="data row3 col0" >4.600000</td>
#       <td id="T_4de47_row3_col1" class="data row3 col1" >0.120000</td>
#       <td id="T_4de47_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_4de47_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_4de47_row3_col4" class="data row3 col4" >0.012000</td>
#       <td id="T_4de47_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_4de47_row3_col6" class="data row3 col6" >6.000000</td>
#       <td id="T_4de47_row3_col7" class="data row3 col7" >0.990070</td>
#       <td id="T_4de47_row3_col8" class="data row3 col8" >2.740000</td>
#       <td id="T_4de47_row3_col9" class="data row3 col9" >0.330000</td>
#       <td id="T_4de47_row3_col10" class="data row3 col10" >8.400000</td>
#       <td id="T_4de47_row3_col11" class="data row3 col11" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4de47_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_4de47_row4_col0" class="data row4 col0" >7.100000</td>
#       <td id="T_4de47_row4_col1" class="data row4 col1" >0.390000</td>
#       <td id="T_4de47_row4_col2" class="data row4 col2" >0.090000</td>
#       <td id="T_4de47_row4_col3" class="data row4 col3" >1.900000</td>
#       <td id="T_4de47_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_4de47_row4_col5" class="data row4 col5" >7.000000</td>
#       <td id="T_4de47_row4_col6" class="data row4 col6" >22.000000</td>
#       <td id="T_4de47_row4_col7" class="data row4 col7" >0.995600</td>
#       <td id="T_4de47_row4_col8" class="data row4 col8" >3.210000</td>
#       <td id="T_4de47_row4_col9" class="data row4 col9" >0.550000</td>
#       <td id="T_4de47_row4_col10" class="d

# %% [raw]
# --By default it will take numerical columns.
#
# --What we need to observe here? --
#
# -->The average value of fixed acidity is 8.31, the highest value is 15.9.
# -->The average value of volatile acidity is 0.52, the highest value is 1.58.
# -->The average value of citric acid is 0.27, the highest value is 1.
# -->The average value of residual sugar is 2.53, the highest value is 15.5.
#
# -BY THIS WE CAN GUESS THE DISTRIBUTION OF THE DATA AND SENSE THE OUTLIERS TOO,
# 1. fixed acidity formed normal distribution.
# 2.'residual sugar' formed right skewed distribution or it have some outliers.
# 3.density forms normal or gaussian distrubution.

# %% [markdown]
# # renaming the columns

# %%
df.rename (columns = 
           {'fixed acidity':'fixed_acidity', 'volatile acidity':'volatile_acidity',
           'citric acid': 'citric_acid', 'residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide',
           'total sulfur dioxide':'total_sulfur_dioxide'}, inplace=True
          )

# %% [markdown]
# # EDA

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
sns.catplot(x='quality',data=df, kind = 'count' )

# %%
# volatile acidity vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'volatile_acidity', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile_acidity'>

# %% [markdown]
# quality feature forms an normal distibution, cause in  the middle  the counts are higher.

# %%
#some color names and their color
purple = ['#491D8B', '#6929C4', '#8A3FFC', '#A56EFF',
          '#BE95FF', '#CA96EC', '#A163CF', '#29066B',
          '#7D3AC1', '#AF4BCE', '#DB4CB2', '#EB548C',
          '#EC96E0', '#A2128E', '#E8D9F3', '#641811']

sns.palplot(purple, size = 2)

# %%
#hist plot is used to plot the distributions of data. used for uni and bivariate analysis

fig, axes = plt.subplots(1,4,figsize = (30, 10)) 

sns.histplot(ax = axes[0], x = df["fixed_acidity"],bins=10,cbar=True,kde=True,color = "#CA96EC").set(title = "Distribution of 'fixed_acidity'");

sns.histplot(ax = axes[1], x = df["volatile_acidity"],bins=10,kde=True).set(title = "Distribution of 'volatile_acidity'");

sns.histplot(ax = axes[2], x = df["citric_acid"],bins = 10,kde = True,cbar=True,color = "#29066B").set(title = "Distribution of 'citric_acid'");

sns.histplot(ax=axes[3], x=df['residual_sugar'], bins=10,cbar=True,kde=True,color='#A163CF').set(title="Distribution of 'residual_sugar'")
# Out:
# [Text(0.5, 1.0, "Distribution of 'residual_sugar'")]

# %% [raw]
# --As we can the values of variable 'fixed acidity' forms relatively normal dist but right skewed. volatile acidity forms 2 peaks(which is bimodal distribution) and citric acid forms 3 peaks(multimodal distribution).
#
# -->What does it mean when a distribution is peaked?
# A peak of a distribution indicates you have a high number of data points in that area of the graph.

# %%
fig, axes = plt.subplots(1, 3, figsize=(40, 10))

sns.histplot(ax = axes[0], x = df["chlorides"],
             bins = 10,    
             kde = True,
             cbar = True,
             color = "#E8D9F3").set(title = "Distribution of 'chlorides'");

sns.histplot(ax = axes[1], x = df["total_sulfur_dioxide"],
             bins = 10,
             kde = True,
             cbar = True,
             color = "#EB548C").set(title = "Distribution of 'total_sulfur_dioxide'");

sns.histplot(ax = axes[2], x = df["alcohol"],
             bins = 10,
             kde = True,   
             cbar = True,
             color = "#EC96E0").set(title = "Distribution of 'alcohol'");

# %% [markdown]
# # PairPlot
# -Used to check the the multicolinearity between independent and dependent varaibles

# %%
#corner true means plot not in rectangle 
sns.pairplot(df,kind='hist',hue='quality',aspect=1.2, corner=True)

# %% [raw]
# --Multicolinearity exists :
# --to deal with this there is analysis such as principal components analysis or partial least squares regression, linear discriminant analysis.

# %%
#now iam using scatter plot again to check the collinearity

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

sns.scatterplot(ax = axes[0],
                x = "residual_sugar",
                y = "quality", hue = "quality",
                data = df).set(title = "Relationship between 'residual_sugar' and 'quality'");

sns.scatterplot(ax = axes[1],
                x = "alcohol",
                y = "quality", hue = "quality",
                data = df).set(title = "Relationship between 'alcohol' and 'quality'");

sns.scatterplot(ax = axes[2],
                x = "pH",
                y = "quality", hue = "quality",
                data = df).set(title = "Relationship between 'pH' and 'quality'");

sns.scatterplot(ax = axes[3],
                x = "density",
                y = "quality", hue = "quality",
                data = df).set(title = "Relationship between 'density' and 'quality'");

# %%
sns.scatterplot(x = "residual_sugar",
                y = "pH",
                hue = "quality",
                data = df).set(title = "Relationship between 'residual_sugar' and 'pH'");

# %% [raw]
# -there is not colinearity between these residual and ph

# %%
sns.scatterplot(x = "alcohol",
                y = "pH",
                hue = "quality",
                palette = "magma",
                data = df).set(title = "Relationship between 'alcohol' and 'pH'");

# %%
plt.figure(figsize = [20, 10])
sns.heatmap(df.corr(), annot = True, linewidths = 2);

# %% [raw]
# --There is 'multicollinearity' problem
#
# Here we see that there is relatively high (0.67, positive) correlation between 'free sulfur dioxide' and 'total_sulfur_dioxide' variables. There is relatively high (-0.68, negative) correlation between "pH" and "fixed_acidity" variables. And there is about 0.5 correlation between some of other variables. That's why we must consider when build Machine Learning models.

# %% [raw]
# --in this dataset we have 6 differenct or unique types of quality, iam dividing into two categories
# 0. 3-5 --low quality
# 1. 6-8 ---high quality

# %%
import numpy as np
df["quality"] = np.where(df["quality"] > 5, 1, 0)
df["quality"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: quality, Length: 1599, dtype: int32

# %% [markdown]
# # Splitting independent and dependent variables

# %%
X = df.drop("quality", axis = 1)
y=df.quality

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, classification_report, accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=101,stratify=y)

# %% [markdown]
# # Model Building

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
rfc = RandomForestClassifier()
boost = AdaBoostClassifier()
gnb=GaussianNB()
mnb=MultinomialNB()
gboost = GradientBoostingClassifier()
xgboost1 = XGBClassifier()

# %%
clfs = {
    'GNB':gnb,
    'NB': mnb, 
    'RF': rfc, 
    'AdaBoost': boost, 
    'GBDT':gboost,
    'xgb':xgboost1
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)

    return accuracy,precision

# %% [markdown]
# # Model Evaluation

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print(name , 'Evaluation report')
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# GNB Evaluation report
# Accuracy -  0.6975
# Precision -  0.7627118644067796
# NB Evaluation report
# Accuracy -  0.645
# Precision -  0.6451612903225806
# RF Evaluation report
# Accuracy -  0.825
# Precision -  0.8428571428571429
# AdaBoost Evaluation report
# Accuracy -  0.725
# Precision -  0.7385321100917431
# GBDT Evaluation report
# Accuracy -  0.7725
# Precision -  0.7971014492753623
# xgb Evaluation report
# Accuracy -  0.805
# Precision -  0.8090909090909091

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")
performance_df1
# Out:
#    Algorithm   variable     value
# 0         RF   Accuracy  0.825000
# 1        xgb   Accuracy  0.805000
# 2       GBDT   Accuracy  0.772500
# 3        GNB   Accuracy  0.697500
# 4   AdaBoost   Accuracy  0.725000
# 5         NB   Accuracy  0.645000
# 6         RF  Precision  0.842857
# 7        xgb  Precision  0.809091
# 8       GBDT  Precision  0.797101
# 9        GNB  Precision  0.762712
# 10  AdaBoost  Precision  0.738532
# 11        NB  Precision  0.645161

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Tuning the RandomForest Model

# %%
from sklearn.model_selection import RandomizedSearchCV
#random_cv = RandomizedSearchCV()@

# %%
n_estimators = [int(x) for x in np.linspace(start=80, stop=200, num=10)]

max_features = ['auto','sqrt']

max_depth = [int(x) for x in np.linspace(4,20,num=8)]

min_samples_split = [2,5,10,15,100]

min_samples_leaf = [1,2,5,10]

# %%
RF_tuning = {'n_estimators': n_estimators,
          'max_features':max_features,
            'max_depth':max_depth,
           'min_samples_split':min_samples_split,
           'min_samples_leaf':min_samples_leaf
          }


print(RF_tuning)
# Out:
# {'n_estimators': [80, 93, 106, 120, 133, 146, 160, 173, 186, 200], 'max_features': ['auto', 'sqrt'], 'max_depth': [4, 6, 8, 10, 13, 15, 17, 20], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(rfc, param_distributions=RF_tuning,
                             scoring='neg_mean_squared_error',cv=5,random_state=101,verbose=2,n_jobs=1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=120; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=120; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=173; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=173; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=173; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=173; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=173; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=93; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=93; total time=   0.1s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=93; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=93; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=93; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.5s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=200; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=146; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=146; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=146; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=146; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=146; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=146; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=146; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=146; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=146; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=4, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=146; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=120; total time=   0.2s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=120; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=160; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=160; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=160; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=160; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=160; total time=   0.3s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=186; total time=   0.5s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=186; total time=   0.5s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=186; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=186; total time=   0.5s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=186; total time=   0.4s
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=1,
#                    param_distributions={'max_depth': [4, 6, 8, 10, 13, 15, 17,
#                                                       20],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [80, 93, 106, 120, 133,
#                                                          146, 160, 173, 186,
#                                                          200]},
#                    random_state=101, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 186,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 13}

# %%
forest = RandomForestClassifier(n_estimators=186, min_samples_split=5, min_samples_leaf=2,max_features='auto',max_depth=13)

# %%
forest.fit(X_train,y_train)
# Out:
# C:\Users\Bhargav\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=13, max_features='auto', min_samples_leaf=2,
#                        min_samples_split=5, n_estimators=186)

# %%
prediction = forest.predict(X_test)

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.8025

# %%
precision_score(y_test,prediction)
# Out:
# 0.813953488372093

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       186
#            1       0.81      0.82      0.82       214
#
#     accuracy                           0.80       400
#    macro avg       0.80      0.80      0.80       400
# weighted avg       0.80      0.80      0.80       400

# %% [markdown]
# # Tuning XGboost

# %%
params = {'max_depth': [3, 6, 10, 15],
              'learning_rate': [0.01, 0.1, 0.2, 0.3, 0.4],
              'subsample': np.arange(0.5, 1.0, 0.1),
              'colsample_bytree': np.arange(0.5, 1.0, 0.1),
              'colsample_bylevel': np.arange(0.5, 1.0, 0.1),
              'n_estimators': [80, 93, 106, 120, 133, 146, 160, 173, 186, 200,213,226],
              'num_class': [10]
              }

# %%
xgboost = XGBClassifier(objective="multi:softmax", tree_method='hist',)
clf = RandomizedSearchCV(estimator=xgboost,
                             param_distributions=params,
                             scoring='accuracy',
                             n_iter=25,
                             n_jobs=4,
                             verbose=1)

# %%
clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# RandomizedSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=None,
#                                            gpu_id=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=None, max_bin=None,
#                                            max_c...
#                    n_iter=25, n_jobs=4,
#                    param_distributions={'colsample_bylevel': array([0.5, 0.6, 0.7, 0.8, 0.9]),
#                                         'colsample_bytree': array([0.5, 0.6, 0.7, 0.8, 0.9]),
#                                         'learning_rate': [0.01, 0.1, 0.2, 0.3,
#                                                           0.4],
#                                         'max_depth': [3, 6, 10, 15],
#                                         'n_estimators': [80, 93, 106, 120, 133,
#                                                          146, 160, 173, 186,
#                                                          200, 213, 226],
#                                         'num_class': [10],
#                                         'subsample': array([0.5, 0.6, 0.7, 0.8, 0.9])},
#                    scoring='accuracy', verbose=1)

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81       186
#            1       0.83      0.85      0.84       214
#
#     accuracy                           0.82       400
#    macro avg       0.82      0.82      0.82       400
# weighted avg       0.82      0.82      0.82       400

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8225

# %% [markdown]
# --I got best accuracy by using XGBoost.

# %% [markdown]
# # Saving the Model

# %%
import pickle

# %%
filename = 'xgboost_wine.pkl'
pickle.dump(clf,open(filename, 'wb'))

# %%
#how to load and using saved model
#rb-reading the binary formatted files
loaded_model = pickle.load(open('xgboost_wine.pkl','rb'))
